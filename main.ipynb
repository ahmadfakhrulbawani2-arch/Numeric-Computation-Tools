# %% [markdown]
# # Numeric Computation Tool
#
# Is a tool created by Ahmad Fakhrul Bawani to calculate functional problem with numerical approach

# %% [markdown]
# ## Prerequisites (!Important)
# Before you go deeper, you need to read my prerequisites regarding dependency and environment setup. My explanation can be found [here](./README.md#how-to-Run).

# %% [markdown]
# ## Importing Dependency
# List dependency in [here](./requirements.txt) and you need to setup the environment first. <br />
# So for brief directory structure is like this:
#
# ```txt
# +---docs                                                                 # placing images
# |       main.png
# |       Programs.jpeg
# |       Wikipedia_Newton-Raphson_Demo.gif
# |
# +---input                                                                # input stdin for programs
# |   +---bisection_method
# |   |       .gitkeep
# |   |
# |   +---faktorisasi
# |   |       .gitkeep
# |   |
# |   +---linear_regression
# |   |       .gitkeep
# |   |       cloud_table.csv
# |   |       table.csv
# |   |
# |   +---newton_raphson
# |   |       .gitkeep
# |   |
# |   +---newton_raphson_modified
# |   |       .gitkeep
# |   |
# |   +---polynomial_regression
# |   |       .gitkeep
# |   |       main_table.csv
# |   |
# |   +---regula_falsi
# |   |       .gitkeep
# |   |
# |   \---secant_method
# |           .gitkeep
# |
# +---out                                                                 # output stdout and its result
# |   +---faktorisasi
# |   |       iterations.csv
# |   |       root.txt
# |   |
# |   +---linear_regression
# |   |       result.txt
# |   |
# |   +---newton-raphson-modified
# |   |       .gitkeep
# |   |       iterations.csv
# |   |       root.txt
# |   |
# |   +---regula-falsi
# |   |       normalize.csv
# |   |       regula_falsi.csv
# |   |       root.txt
# |   |
# |   \---secant-method
# |           iterations.csv
# |           root.txt
# |
# +---resources                                                           # brief math detail
# |   |   bisection-method.tex
# |   |   faktorisasi-iteratif.tex
# |   |   newton-raphson-modified.tex
# |   |   newton-raphson.tex
# |   |   regula-falsi.tex
# |   |   secant-method.tex
# |   |
# |   +---class
# |   |       PERTEMUAN 10.pdf
# |   |       PERTEMUAN 11.pdf
# |   |       PERTEMUAN 13.pdf
# |   |       PERTEMUAN 14.pdf
# |   |       PERTEMUAN 15.pdf
# |   |       PERTEMUAN 1_ppt_1_bilqis_pengertian.pptx
# |   |       PERTEMUAN 2_Grafik, Tabulasi, Bisection, RegulaFalsi.pptx
# |   |       PERTEMUAN 3_Iterasi Satu Titik Sederhana, Newton-Raphson, Secant.pdf
# |   |       PERTEMUAN 5_Newton-Raphson Modifikasi, Faktorisasi.pdf
# |   |       PERTEMUAN 6_Regresi Linier, Aplikasinya dan Regresi Polynomial.pdf
# |   |       PERTEMUAN 7.pdf
# |   |       PERTEMUAN 9_Interpolasi Newton dan Lagrange.pdf
# |   |
# |   \---pdf
# |           faktorisasi-numerik-lin-method.pdf
# |           regresi-linier-dan-polinomial.pdf
# |
# +---scripts                                                            # just my scripts to run the program
# |       lint.ps1
# |       lint.sh
# |       run.ps1
# |       run.sh
# |
# \---src                                                                # programs source
#     |   __init__.py
#     |
#     +---bisection_method                                               # each program is one dir btw
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---chapter_6_1_linear_regression
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---chapter_6_2_polynomial_regression
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---faktorisasi
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---newton_raphson
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---newton_raphson_modified
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---regula_falsi
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---secant_method
#     |   |   index.py
#     |   |   README.md
#     |   |   run.ps1
#     |   |   run.sh
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           index.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     +---utils                                                          # function utility and helper so it's modular
#     |   |   FuncUtils.py
#     |   |   IoUtils.py
#     |   |   Logger.py
#     |   |   Style.py
#     |   |   __init__.py
#     |   |
#     |   \---__pycache__
#     |           FuncUtils.cpython-312.pyc
#     |           IoUtils.cpython-312.pyc
#     |           Logger.cpython-312.pyc
#     |           Style.cpython-312.pyc
#     |           __init__.cpython-312.pyc
#     |
#     \---__pycache__
#             __init__.cpython-312.pyc
# ```

# %%
# %pip install numpy 
import numpy as np
from typing import List
from src.utils.FuncUtils import *
from src.utils.IoUtils import *

import numpy as np
from datetime import datetime
